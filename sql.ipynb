# %%
import numpy as np
import pandas as pd
import os
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
import psycopg2
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    host = 'postgres',
    port = 5432,
    db = 'artipy'
))

# %% [markdown]
# # Impressionism

# %% [markdown]
# Impressionism, in music, a style initiated by French composer Claude Debussy at the end of the 19th century. The term, which is somewhat vague in reference to music, was introduced by analogy with contemporaneous French painting; it was disliked by Debussy himself. Elements often termed impressionistic include static harmony, emphasis on instrumental timbres that creates a shimmering interplay of “colours,” melodies that lack directed motion, surface ornamentation that obscures or substitutes for melody, and an avoidance of traditional musical form. Impressionism can be seen as a reaction against the rhetoric of Romanticism, disrupting the forward motion of standard harmonic progressions. The other composer most often associated with Impressionism is Maurice Ravel. Impressionistic passages are common in earlier music by Frédéric Chopin, Franz Liszt, and Richard Wagner, and in music by later composers such as Charles Ives, Béla Bartók, and George Gershwin.

# %% [markdown]
# debussy '1Uff91EOsvd99rtAupatMP'
# ravel '17hR0sYHpx7VYTMRfFUOmY'

# %%
myquery = '''
SELECT name,
       preview_url,
       artists_names, 
       first_artist_id,
       album_image,
       album_name,
       release_date,
       danceability,
       energy,
       loudness,
       speechiness,
       acousticness,
       instrumentalness,
       valence,
       tempo
       
FROM spotify
WHERE first_artist_id = '17hR0sYHpx7VYTMRfFUOmY' 
    OR first_artist_id ='1Uff91EOsvd99rtAupatMP' 
    AND preview_url != 'None'
ORDER BY popularity

'''

df = pd.read_sql_query(myquery, con=engine)
df
# Out:
#                                                  name  \
# 0   Préludes, Book I, L. 117: VIII. La fille aux c...
# 1                           La plus que lente, L. 121
# 2   Pelléas et Mélisande, L. 88: Act I: Scene I, U...
# 3                  Images: No. 3. Rondes de printemps
# 4   Préludes, Book 2, L. 123: No. 12, Feux d'artifice
# ..                                                ...
# 61  Petite suite: I. En bateau (arr. H. Busser for...
# 62  Suite Bergamasque, L. 75: III. Clair de lune (...
# 63                                     Rêverie, L. 68
# 64      Ravel: Pavane pour une infante défunte, M. 19
# 65                               Clair de Lune, L. 32
#
#                                           preview_url  \
# 0   https://p.scdn.co/mp3-preview/8a26e954352f018c...
# 1   https://p.scdn.co/mp3-preview/2a3e6a656e37ce14...
# 2   https://p.scdn.co/mp3-preview/d086618870576491...
# 3   https://p.scdn.co/mp3-preview/556c0abf966c7e00...
# 4   https://p.scdn.co/mp3-preview/cbc7a1930b471337...
# ..                                                ...
# 61  https://p.scdn.co/mp3-preview/13ca285f48b4a5d7...
# 62  https://p.scdn.co/mp3-preview/f2d1af88e0bb65c0...
# 63  https://p.scdn.co/mp3-preview/62d5a631c304ef21...
# 64  https://p.scdn.co/mp3-preview/759005c6c03aa4eb...
# 65  https://p.scdn.co/mp3-preview/5be874064e3a3d0b...
#
#                                         artists_names         first_artist_id  \
# 0                       Claude Debussy, Axel Gillison  1Uff91EOsvd99rtAupatMP
# 1                       Claude Debussy, Axel Gillison  1Uff91EOsvd99rtAupatMP
# 2   Claude Debussy, Pierre Boulez, Orchestra of th...  1Uff91EOsvd99rtAupatMP
# 3   Claude Debussy, Orchestre National De Lyon, Ju...  1Uff91EOsvd99rtAupatMP
# 4                   Claude Debussy, Paavali Jumppanen  1Uff91EOsvd99rtAupatMP
# ..                                                ...                     ...
# 61  Claude Debussy, Henri Büsser, Orchestre Nation...  1Uff91EOsvd99rtAupatMP
# 62                       Claude Debussy, Alain Planès  1Uff91EOsvd99rtAupatMP
# 63                       Claude Debussy, Alain Planès  1Uff91EOsvd99rtAupatMP
# 64                   Maurice Ravel, Bertrand Chamayou  17hR0sYHpx7VYTMRfFUOmY
# 65                       Claude Debussy, Martin Jones  1Uff91EOsvd99rtAupatMP
#
#                                           album_image  \
# 0   https://i.scdn.co/image/ab67616d00001e02cfb761...
# 1   https://i.scdn.co/image/ab67616d00001e02cfb761...
# 2   https://i.scdn.co/image/ab67616d00001e02faca6f...
# 3   https://i.scdn.co/image/ab67616d00001e02426245...
# 4   https://i.scdn.co/image/ab67616d00001e0248a15c...
# ..                                                ...
# 61  https://i.scdn.co/image/ab67616d00001e02debd4c...
# 62  https://i.scdn.co/image/ab67616d00001e02cd9397...
# 63  https://i.scdn.co/image/ab67616d00001e02a13a0c...
# 64  https://i.scdn.co/image/ab67616d00001e02717e9f...
# 65  https://i.scdn.co/image/ab67616d00001e026e7bb2...
#
#                                            album_name release_date  \
# 0                                Debussy Piano Pieces   2020-08-29
# 1                                Debussy Piano Pieces   2020-08-29
# 2                       Debussy: Pelléas et Mélisande         1970
# 3                   Debussy: Orchestral Works, Vol. 3   2010-03-30
# 4               Debussy: Préludes & Children's Corner   2018-01-12
# ..                                                ...          ...
# 61                  Debussy: Orchestral Works, Vol. 6   2011-05-03
# 62  Debussy: Children's Corner, Suite bergamasque,...   2007-07-31
# 63  Debussy: Estampes; Pour le piano; 6 épigraphes...   2007-07-31
# 64               Ravel: Complete Works for Solo Piano   2016-01-15
# 65  Debussy: Clair De Lune and Other Piano Favourites         1994
#
#     danceability   energy  loudness  speechiness  acousticness  \
# 0          0.431  0.00527   -32.617       0.0587         0.995
# 1          0.278  0.01340   -30.358       0.0518         0.994
# 2          0.172  0.07010   -24.149       0.0552         0.981
# 3          0.135  0.12400   -24.660       0.0535         0.957
# 4          0.350  0.09260   -21.264       0.0401         0.991
# ..           ...      ...       ...          ...           ...
# 61         0.142  0.01520   -30.817       0.0377         0.964
# 62         0.360  0.02490   -27.017       0.0463         0.993
# 63         0.250  0.00904   -31.617       0.0410         0.995
# 64         0.491  0.01760   -26.911       0.0644         0.994
# 65         0.335  0.00532   -31.646       0.0376         0.994
#
#     instrumentalness  valence    tempo
# 0             0.9320   0.1640   69.908
# 1             0.9050   0.0652   66.391
# 2             0.0747   0.0366   75.920
# 3             0.8250   0.0737   67.599
# 4             0.7640   0.0320  134.121
# ..               ...      ...      ...
# 61            0.8540   0.0746   92.621
# 62            0.9320   0.0396  133.024
# 63            0.9220   0.0830   62.541
# 64            0.9270   0.0901  125.793
# 65            0.9120   0.0397   65.832
#
# [66 rows x 15 columns]

# %%
d_mean = df['danceability'].mean().round(3)
d_var = df['danceability'].var().round(3)

e_mean = df['energy'].mean().round(3)
e_var = df['energy'].var().round(3)

l_mean = df['loudness'].mean().round(3)
l_var = df['loudness'].var().round(3)

s_mean = df['speechiness'].mean().round(3)
s_var = df['speechiness'].var().round(3)

a_mean = df['acousticness'].mean().round(3)
a_var = df['acousticness'].var().round(3)

i_mean = df['instrumentalness'].mean().round(3)
i_var = df['instrumentalness'].var().round(3)

v_mean = df['valence'].mean().round(3)
v_var = df['valence'].var().round(3)

t_mean = df['tempo'].mean().round(3)
t_var = df['tempo'].var().round(3)

results = f'danceability: ({d_mean},{d_var}],\nenergy: ({e_mean},{e_var}],\nloudness: ({l_mean},{l_var}],\nspeechiness: ({s_mean},{s_var}],\nacousticness: ({a_mean},{a_var}],\ninstrumentalness: ({i_mean},{i_var}],\nvalence: ({v_mean},{v_var}],\ntempo: ({t_mean},{t_var}])'
print(results)
# Out:
# danceability: (0.267,0.011],
# energy: (0.043,0.002],
# loudness: (-28.591,31.49],
# speechiness: (0.045,0.0],
# acousticness: (0.976,0.001],
# instrumentalness: (0.818,0.04],
# valence: (0.097,0.006],
# tempo: (95.288,1234.36])

# %% [markdown]
# ## Get similar songs

# %%
myquery = f'''
SELECT name,
       preview_url,
       artists_names, 
       first_artist_id,
       album_image,
       album_name,
       release_date,
       danceability,
       energy,
       speechiness,
       acousticness,
       valence
       
FROM spotify
WHERE danceability > {max(d_mean - .05, 0)} AND danceability < {min(d_mean + .05, 1)}
    AND energy > {max(e_mean - .05, 0)} AND energy < {min(e_mean + .05, 1)}
    AND speechiness > {max(s_mean - .05, 0)} AND speechiness < {min(s_mean + .05, 1)}
    AND acousticness > {max(a_mean - .05, 0)} AND acousticness < {min(a_mean + .05, 1)}
    AND valence > {max(v_mean - .05, 0)} AND valence < {min(v_mean + .05, 1)}
    AND first_artist_id != '17hR0sYHpx7VYTMRfFUOmY' 
    AND first_artist_id !='1Uff91EOsvd99rtAupatMP' 
    AND preview_url != 'None'
'''

df = pd.read_sql_query(myquery, con=engine)
df
# Out:
#                                               name  \
# 0    Scheherazade: The Tale of the Kalendar Prince
# 1                                       På Örnjakt
# 2                       Cancion de cuna (Berceuse)
# 3                                          No Cure
# 4                                           テリフリアメ
# ..                                             ...
# 108                             Sicilienne, Op. 78
# 109                             Asturias (Leyenda)
# 110                            I en cirkel af sten
# 111                                        Passage
# 112                                          Smile
#
#                                            preview_url  \
# 0    https://p.scdn.co/mp3-preview/1f342f2479f0fe6a...
# 1    https://p.scdn.co/mp3-preview/6f11fd6ef971dbdb...
# 2    https://p.scdn.co/mp3-preview/7bd8e4d8e1a8253e...
# 3    https://p.scdn.co/mp3-preview/de40544e18330021...
# 4    https://p.scdn.co/mp3-preview/b444adf0800e9228...
# ..                                                 ...
# 108  https://p.scdn.co/mp3-preview/36128601ace04bb6...
# 109  https://p.scdn.co/mp3-preview/e663aa550194264e...
# 110  https://p.scdn.co/mp3-preview/5cc25b92c35e9874...
# 111  https://p.scdn.co/mp3-preview/5df9b136ebe5eeb0...
# 112  https://p.scdn.co/mp3-preview/43c307731cf41c1d...
#
#                                         artists_names         first_artist_id  \
# 0        Nikolai Rimsky-Korsakov, Lars Hjalmar Joakim  2kXJ68O899XvWOBdpzlXgs
# 1                                      Simon Berggren  2bFX68G72HV65jnweXUeWd
# 2                           Leo Brouwer, Marco Tamayo  4PdumqEAuo2EQzukVWnxa0
# 3                                     Joel Lyssarides  6OMYcSur3Y0DthpzbVkxAx
# 4                                         Ichiko Aoba  6ignRjbPmLvKdtMLj9a5Xs
# ..                                                ...                     ...
# 108  Gabriel Fauré, Harriet Krijgh, Kamilla Isanbaeva  2gClsBep1tt1rv1CN210SO
# 109                     Isaac Albéniz, Simon Dinnigan  4sbcjbyksdT4dJ5Lh0SvZp
# 110                             Asynje, Nanna Barslev  42mveNsBgkZr7J2aMZQouQ
# 111                                 Joanne Shenandoah  1FrutbnuSr4cDQGGf63HDf
# 112                                     Janelle Monáe  6ueGR6SWhUJfvEhqkvMsVs
#
#                                            album_image  \
# 0    https://i.scdn.co/image/ab67616d00001e02734ead...
# 1    https://i.scdn.co/image/ab67616d00001e02298f4b...
# 2    https://i.scdn.co/image/ab67616d00001e0279de29...
# 3    https://i.scdn.co/image/ab67616d00001e02f9fc08...
# 4    https://i.scdn.co/image/ab67616d00001e02a49dba...
# ..                                                 ...
# 108  https://i.scdn.co/image/ab67616d00001e0212e6ef...
# 109  https://i.scdn.co/image/ab67616d00001e02d951b9...
# 110  https://i.scdn.co/image/ab67616d00001e02052204...
# 111  https://i.scdn.co/image/ab67616d00001e02fdddf5...
# 112  https://i.scdn.co/image/ab67616d00001e02b72cb7...
#
#                                         album_name release_date  danceability  \
# 0                    Rimsky-Korsakov: Scheherezade   1999-02-01         0.235
# 1                                        Piano - I   2022-03-21         0.254
# 2                           Guitar Music From Cuba   2004-03-22         0.266
# 3                                          No Cure   2023-02-17         0.282
# 4                                               qp   2018-10-24         0.271
# ..                                             ...          ...           ...
# 108                               The French Album   2012-04-03         0.293
# 109                         Favourite Guitar Works   1998-07-16         0.275
# 110                                       Genkaldt   2012-01-24         0.257
# 111                       The Best of Tribal Music   2014-06-17         0.272
# 112  Metropolis: The Chase Suite (Special Edition)   2008-08-12         0.242
#
#      energy  speechiness  acousticness  valence
# 0    0.0639       0.0490         0.962   0.0781
# 1    0.0640       0.0348         0.988   0.0567
# 2    0.0168       0.0431         0.994   0.1440
# 3    0.0685       0.0417         0.947   0.1090
# 4    0.0478       0.0350         0.966   0.0560
# ..      ...          ...           ...      ...
# 108  0.0677       0.0472         0.981   0.0994
# 109  0.0863       0.0516         0.972   0.1460
# 110  0.0431       0.0440         0.959   0.1370
# 111  0.0197       0.0526         0.987   0.1330
# 112  0.0692       0.0377         0.933   0.1280
#
# [113 rows x 12 columns]

# %% [markdown]
# # Pop Art

# %% [markdown]
# https://ohiostate.pressbooks.pub/artandmusicbiographies/chapter/reading-4-pop-art-and-new-rock/
